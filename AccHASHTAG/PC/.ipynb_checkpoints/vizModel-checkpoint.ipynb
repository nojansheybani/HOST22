# %%
from PreProcessing import *
from torchviz import make_dot
from torch.utils.tensorboard import SummaryWriter
import torch.nn.functional as F
writer=SummaryWriter('./logsdir')

# %%
preprocess()
lenet5 = LeNet5()
# lenet5.load_state_dict(torch.load("lenet.pth"))

# %%
x = torch.randn(1,28,28)
y = lenet5(x)

# %%
make_dot(y.mean(), params=dict(lenet5.named_parameters()), show_attrs=True, show_saved=True)

# %%
while True:
    layerToModify = 2
    attackedModel = bitFlip(model, layers[layerToModify])
    communicate()
